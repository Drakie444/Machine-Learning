# %% [markdown]
# <a href="https://colab.research.google.com/github/Drakie444/Machine-Learning/blob/main/weather_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installl all requirements

# %%
# !pip install keras~=3.8.0 \
  matplotlib~=3.10.0 \
  numpy~=2.0.0 \
  pandas~=2.2.0 \
  tensorflow~=2.18.0

print('\n\nAll requirements successfully installed.')
# Out:
# Collecting google-ml-edu==0.1.3
#   Downloading google_ml_edu-0.1.3-py3-none-any.whl.metadata (1.4 kB)
# Collecting keras~=3.8.0
#   Downloading keras-3.8.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: matplotlib~=3.10.0 in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: numpy~=2.0.0 in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas~=2.2.0 in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Collecting tensorflow~=2.18.0
#   Downloading tensorflow-2.18.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras~=3.8.0) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras~=3.8.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras~=3.8.0) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras~=3.8.0) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras~=3.8.0) (0.19.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras~=3.8.0) (0.5.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras~=3.8.0) (26.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas~=2.2.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas~=2.2.0) (2026.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow~=2.18.0) (1.82.1)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow~=2.18.0)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow~=2.18.0) (0.47.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow~=2.18.0) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow~=2.18.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow~=2.18.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow~=2.18.0) (2026.6.17)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.19,>=2.18->tensorflow~=2.18.0) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.19,>=2.18->tensorflow~=2.18.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.19,>=2.18->tensorflow~=2.18.0) (3.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras~=3.8.0) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras~=3.8.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras~=3.8.0) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow~=2.18.0) (3.0.3)
# Downloading google_ml_edu-0.1.3-py3-none-any.whl (9.4 kB)
# Downloading keras-3.8.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.4 MB/s eta 0:00:00
# Downloading tensorflow-2.18.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (615.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.6/615.6 MB 990.6 kB/s eta 0:00:00
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 36.0 MB/s eta 0:00:00
# Installing collected packages: tensorboard, keras, tensorflow, google-ml-edu
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.20.0
#     Uninstalling tensorboard-2.20.0:
#       Successfully uninstalled tensorboard-2.20.0
#   Attempting uninstall: keras
#     Found existing installation: keras 3.13.2
#     Uninstalling keras-3.13.2:
#       Successfully uninstalled keras-3.13.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.20.0
#     Uninstalling tensorflow-2.20.0:
#       Successfully uninstalled tensorflow-2.20.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.20.0 requires tensorflow<2.21,>=2.20, but you have tensorflow 2.18.1 which is incompatible.
# keras-hub 0.26.0 requires keras>=3.13, but you have keras 3.8.0 which is incompatible.
# ydf-tf 2.20.0 requires tensorflow==2.20.0, but you have tensorflow 2.18.1 which is incompatible.
# tensorflow-text 2.20.1 requires tensorflow<2.21,>=2.20.0, but you have tensorflow 2.18.1 which is incompatible.
# Successfully installed google-ml-edu-0.1.3 keras-3.8.0 tensorboard-2.18.0 tensorflow-2.18.1
#
#
# All requirements successfully installed.

# %% [markdown]
# # Required imports

# %%
# data
import numpy as np
import pandas as pd

# machine learning
import keras

# data visualization
import matplotlib.pyplot as plt


# load google drive
from google.colab import drive

drive.mount('/content/drive')

#scaling the data
from sklearn.preprocessing import StandardScaler

#computing class weights
from sklearn.utils.class_weight import compute_class_weight
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Weather dataset loading

# %%
weather_data = pd.read_csv("/content/drive/MyDrive/Colab/open-meteo.csv", skiprows=3)

# %% [markdown]
# Wyświetlenie załadowanych danych (10 wierszy) i opis statystyk danych

# %%
weather_data.head(10)
# Out:
#                time  temperature_2m (°C)  relative_humidity_2m (%)  rain (mm)  \
# 0  2023-01-01T00:00                 13.9                        74        0.0
# 1  2023-01-01T01:00                 13.8                        71        0.0
# 2  2023-01-01T02:00                 14.4                        68        0.0
# 3  2023-01-01T03:00                 13.7                        71        0.0
# 4  2023-01-01T04:00                 14.0                        67        0.0
# 5  2023-01-01T05:00                 14.0                        64        0.0
# 6  2023-01-01T06:00                 13.9                        62        0.0
# 7  2023-01-01T07:00                 14.8                        57        0.0
# 8  2023-01-01T08:00                 14.7                        58        0.0
# 9  2023-01-01T09:00                 13.7                        60        0.0
#
#    wind_speed_10m (km/h)  surface_pressure (hPa)  cloud_cover (%)
# 0                   25.9                  1001.0              100
# 1                   26.0                  1000.9              100
# 2                   25.7                  1000.8               99
# 3                   27.0                  1001.2              100
# 4                   28.7                  1001.0              100
# 5                   28.3                  1001.3              100
# 6                   27.3                  1001.6              100
# 7                   27.2                  1001.4               99
# 8                   26.3                  1002.2              100
# 9                   25.3                  1002.8               28

# %%
weather_data.describe()
# Out:
#        temperature_2m (°C)  relative_humidity_2m (%)     rain (mm)  \
# count         26304.000000              26304.000000  26304.000000
# mean             10.692587                 74.426095      0.066708
# std               8.554558                 17.929821      0.390751
# min             -13.800000                 17.000000      0.000000
# 25%               3.700000                 62.000000      0.000000
# 50%              10.000000                 78.000000      0.000000
# 75%              17.400000                 89.000000      0.000000
# max              35.000000                100.000000     20.100000
#
#        wind_speed_10m (km/h)  surface_pressure (hPa)  cloud_cover (%)
# count           26304.000000            26304.000000     26304.000000
# mean               13.064811             1002.139078        66.663055
# std                 6.423026                9.039903        40.894495
# min                 0.000000              964.000000         0.000000
# 25%                 8.300000              996.700000        22.000000
# 50%                12.200000             1002.400000        97.000000
# 75%                16.900000             1007.900000       100.000000
# max                43.800000             1031.800000       100.000000

# %% [markdown]
# Separating and normalizing the data

# %%
weather_data.columns
# Out:
# Index(['time', 'temperature_2m (°C)', 'relative_humidity_2m (%)', 'rain (mm)',
#        'wind_speed_10m (km/h)', 'surface_pressure (hPa)', 'cloud_cover (%)'],
#       dtype='object')

# %%
#Converting the time to the hour and month because the weather is dependend on the season
weather_data["time"] = pd.to_datetime(weather_data["time"])
weather_data["hour"] = weather_data["time"].dt.hour
weather_data["month"] = weather_data["time"].dt.month


#converting the time into sin and cos function in order to allow the model to see the the hours as a cycle. The values of the sin and cos function will diffenciate all hours in a day allowing every hour to have a unique position.
weather_data["hour_sin"] = np.sin(
    2 * np.pi * weather_data["hour"] / 24
)

weather_data["hour_cos"] = np.cos(
    2 * np.pi * weather_data["hour"] / 24
)

weather_data["month_sin"] = np.sin(
    2 * np.pi * weather_data["month"] / 12
)

weather_data["month_cos"]  = np.cos(
    2 * np.pi * weather_data["month"] / 12
)

weather_data = weather_data.rename(columns={
    'wind_speed_10m (km/h)': 'wind_speed_10m_kmh'
})


#adding the columns checking the pressure change and humidity change - both metrics indicate the upcomming rain

weather_data['is_raining_now'] = (weather_data['rain (mm)'] > 0).astype(int)
weather_data['pressure_change'] = weather_data['surface_pressure (hPa)'].diff(1)
weather_data['humidity_change'] = weather_data['relative_humidity_2m (%)'].diff(1)

weather_data = weather_data.dropna()

#shifting the rain label to allow model to learn to predict the rain in the next hour
weather_data["rain_next_hour"] = (weather_data["rain (mm)"].shift(-1) > 0).astype(int)
weather_data = weather_data.dropna(subset=["rain_next_hour"])

labels = weather_data["rain_next_hour"]

feature_labels = ['hour_sin', 'hour_cos', 'month_sin', 'month_cos', 'temperature_2m (°C)', 'relative_humidity_2m (%)',
       'wind_speed_10m_kmh', 'surface_pressure (hPa)', 'cloud_cover (%)', 'is_raining_now', 'pressure_change', 'humidity_change']
features = weather_data[feature_labels]

features.head(20)
# Out:
#         hour_sin      hour_cos  month_sin  month_cos  temperature_2m (°C)  \
# 1   2.588190e-01  9.659258e-01        0.5   0.866025                 13.8
# 2   5.000000e-01  8.660254e-01        0.5   0.866025                 14.4
# 3   7.071068e-01  7.071068e-01        0.5   0.866025                 13.7
# 4   8.660254e-01  5.000000e-01        0.5   0.866025                 14.0
# 5   9.659258e-01  2.588190e-01        0.5   0.866025                 14.0
# 6   1.000000e+00  6.123234e-17        0.5   0.866025                 13.9
# 7   9.659258e-01 -2.588190e-01        0.5   0.866025                 14.8
# 8   8.660254e-01 -5.000000e-01        0.5   0.866025                 14.7
# 9   7.071068e-01 -7.071068e-01        0.5   0.866025                 13.7
# 10  5.000000e-01 -8.660254e-01        0.5   0.866025                 13.9
# 11  2.588190e-01 -9.659258e-01        0.5   0.866025                 14.8
# 12  1.224647e-16 -1.000000e+00        0.5   0.866025                 15.4
# 13 -2.588190e-01 -9.659258e-01        0.5   0.866025                 15.5
# 14 -5.000000e-01 -8.660254e-01        0.5   0.866025                 15.7
# 15 -7.071068e-01 -7.071068e-01        0.5   0.866025                 15.3
# 16 -8.660254e-01 -5.000000e-01        0.5   0.866025                 14.7
# 17 -9.659258e-01 -2.588190e-01        0.5   0.866025                 14.0
# 18 -1.000000e+00 -1.836970e-16        0.5   0.866025                 13.5
# 19 -9.659258e-01  2.588190e-01        0.5   0.866025                 12.8
# 20 -8.660254e-01  5.000000e-01        0.5   0.866025                 11.7
#
#     relative_humidity_2m (%)  wind_speed_10m_kmh  surface_pressure (hPa)  \
# 1                         71                26.0                  1000.9
# 2                         68                25.7                  1000.8
# 3                         71                27.0                  1001.2
# 4                         67                28.7                  1001.0
# 5                         64                28.3                  1001.3
# 6                         62                27.3                  1001.6
# 7                         57                27.2                  1001.4
# 8                         58                26.3                  1002.2
# 9                         60                25.3                  1002.8
# 10                        60                24.5                  1003.2
# 11                        57                25.5                  1003.6
# 12                        57                24.5                  1003.7
# 13                        58                23.5                  1003.7
# 14                        57                23.9                  1003.5
# 15                        58                24.1                  1003.8
# 16                        60                23.5                  1004.4
# 17                        62                21.4                  1005.0
# 18                        63                20.6                  1005.7
# 19                        66                18.5                  1006.3
# 20                        70                17.6                  1006.7
#
#     cloud_cover (%)  is_raining_now  pressure_change  humidity_change
# 1               100               0             -0.1             -3.0
# 2                99               0             -0.1             -3.0
# 3               100               0              0.4              3.0
# 4               100               0             -0.2             -4.0
# 5               100               0              0.3             -3.0
# 6               100               0              0.3             -2.0
# 7                99               0             -0.2             -5.0
# 8               100               0              0.8              1.0
# 9                28               0              0.6              2.0
# 10               30               0              0.4              0.0
# 11               36               0              0.4             -3.0
# 12               34               0              0.1              0.0
# 13               74               0              0.0              1.0
# 14              100               0             -0.2             -1.0
# 15               93               0              0.3              1.0
# 16              100               0              0.6              2.0
# 17              100               0              0.6              2.0
# 18              100               0              0.7              1.0
# 19              100               0              0.6              3.0
# 20              100               0              0.4              4.0

# %% [markdown]
# Separating the training data and testing data

# %%
split = int(len(features) * 0.7)

x_train  = features[:split]
x_test = features[split:]

y_train = labels[:split]
y_test = labels[split:]

# %% [markdown]
# Normalizing data in order to get all features in the same range. Without normalizing the weight would need to have an extreme low or high values resulting in a possibly  low quality model.

# %%
scaler = StandardScaler()


x_train_scaled = pd.DataFrame(
    scaler.fit_transform(x_train),
    columns = x_train.columns,
    index = x_train.index
)

x_test_scaled = pd.DataFrame(
    scaler.transform(x_test),
    columns = x_test.columns,
    index = x_test.index

)

x_train_scaled.head(10)
# Out:
#     hour_sin  hour_cos  month_sin  month_cos  temperature_2m (°C)  \
# 1   0.365855  1.365760   0.683118   1.162753             0.355677
# 2   0.706944  1.224483   0.683118   1.162753             0.424521
# 3   0.999844  0.999743   0.683118   1.162753             0.344203
# 4   1.224595  0.706857   0.683118   1.162753             0.378625
# 5   1.365878  0.365783   0.683118   1.162753             0.378625
# 6   1.414068 -0.000233   0.683118   1.162753             0.367151
# 7   1.365878 -0.366250   0.683118   1.162753             0.470417
# 8   1.224595 -0.707324   0.683118   1.162753             0.458943
# 9   0.999844 -1.000210   0.683118   1.162753             0.344203
# 10  0.706944 -1.224950   0.683118   1.162753             0.367151
#
#     relative_humidity_2m (%)  wind_speed_10m_kmh  surface_pressure (hPa)  \
# 1                  -0.197431            1.865120               -0.080490
# 2                  -0.366138            1.820022               -0.090973
# 3                  -0.197431            2.015447               -0.049040
# 4                  -0.422374            2.271003               -0.070007
# 5                  -0.591082            2.210872               -0.038557
# 6                  -0.703554            2.060545               -0.007108
# 7                  -0.984734            2.045512               -0.028074
# 8                  -0.928498            1.910218                0.055791
# 9                  -0.816026            1.759891                0.118690
# 10                 -0.816026            1.639630                0.160622
#
#     cloud_cover (%)  is_raining_now  pressure_change  humidity_change
# 1          0.777846       -0.408132        -0.224755        -0.680639
# 2          0.752990       -0.408132        -0.224755        -0.680639
# 3          0.777846       -0.408132         0.885809         0.680171
# 4          0.777846       -0.408132        -0.446868        -0.907440
# 5          0.777846       -0.408132         0.663697        -0.680639
# 6          0.777846       -0.408132         0.663697        -0.453837
# 7          0.752990       -0.408132        -0.446868        -1.134242
# 8          0.777846       -0.408132         1.774261         0.226567
# 9         -1.011823       -0.408132         1.330035         0.453369
# 10        -0.962110       -0.408132         0.885809        -0.000234

# %% [markdown]
# # Creating a model

# %%
def create_model(
    inputs_features: list[str],
    learning_rate: float,
    metrics: list[keras.metrics.Metric],
) -> keras.Model :

  model_inputs = [
      keras.Input(name=feature, shape=(1, ))
      for feature in inputs_features
  ]

  #we combine the data into a tensor (matrix)
  concatenated_inputs = keras.layers.Concatenate()(model_inputs)


  # adding a hidden relu layer to allow the model to see more corelations in the weather conditions
  x = keras.layers.Dense(32, activation="relu")(concatenated_inputs)

  model_output = keras.layers.Dense(
      units=1, activation="sigmoid"
  )(x)

  model = keras.Model(inputs=model_inputs, outputs=model_output)

  #configuring the model, seting up how the model will change it's weights and how it measure the loss
  model.compile(

      #after calculating the loss, we set the model to use the RMS algorithm and loss and learning rate to calculate the new weights
      #the model needs the Adam algorithm to be able to train properly for weather prediction
      #clipnorm disallows the model for too large optimalization steps
      optimizer = keras.optimizers.Adam(
          learning_rate
      ),
      loss = keras.losses.BinaryCrossentropy(),  #function used to calculate the loss approperiate to the sigmoid fuction
      metrics=metrics
  )

  return model

# %% [markdown]
# # Define the training model function

# %%
def train_model(
    model: keras.Model,
    train_data: pd.DataFrame,
    train_labels: np.ndarray,
    test_data: pd.DataFrame,
    test_labels: np.ndarray,
    inputs_features: list[str],
    batch_size: int,
    epochs: int
):
  x_train = {
      feature_name: np.array(train_data[feature_name])
      for feature_name in inputs_features
  }
  x_test = {
      feature_name: np.array(test_data[feature_name])
      for feature_name in inputs_features
  }

  #adding class weights to allow the model to compute what features are the most important
  weights = compute_class_weight(
      class_weight='balanced',
      classes=np.unique(y_train),
      y=y_train
  )

  class_weight_dict = dict(enumerate(weights))

  history = model.fit(
      x=x_train,
      y=train_labels,
      validation_data = (x_test, test_labels),
      batch_size=batch_size,
      epochs=epochs,
      #adding weights in training
      class_weight=class_weight_dict
  )


  return history

# %% [markdown]
# # Define model metrics
# Metrics are used to validate the model accuracy

# %%
rain_threshold = 0.6

metrics = [
    keras.metrics.BinaryAccuracy(
        name='accuracy', threshold=rain_threshold    #evaluates how many cases the model got correct  (prediction)
    ),
    keras.metrics.Precision(
        name='precision', thresholds=rain_threshold      # evaluates how many cases of all classified by model positives were real positives   (TP/ TP + FP)
    ),
    keras.metrics.Recall(
        name='recall', thresholds=rain_threshold      # how many positive cases out of all positive cases the model was able to find (TP / TP + FN)
    ),
    keras.metrics.AUC(num_thresholds=100, name='auc'),   #AUC - area under the curve shows how well the model can diffrenciate one case from the other
]

# %% [markdown]
# Invoke the creating and training functions

# %%
learning_rate = 0.001

model = create_model(feature_labels, learning_rate, metrics)

history = train_model(
    model = model,
    train_data = x_train_scaled,
    train_labels = y_train,
    test_data = x_test_scaled,
    test_labels = y_test,
    inputs_features = feature_labels,
    batch_size=64,
    epochs=35
)
# Out:
# Epoch 1/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.8725 - auc: 0.8896 - loss: 0.5225 - precision: 0.5241 - recall: 0.7075 - val_accuracy: 0.9136 - val_auc: 0.9179 - val_loss: 0.3432 - val_precision: 0.6473 - val_recall: 0.7237
# Epoch 2/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9016 - auc: 0.9107 - loss: 0.3752 - precision: 0.6391 - recall: 0.7241 - val_accuracy: 0.9136 - val_auc: 0.9207 - val_loss: 0.3248 - val_precision: 0.6486 - val_recall: 0.7188
# Epoch 3/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9080 - auc: 0.9151 - loss: 0.3614 - precision: 0.6565 - recall: 0.7199 - val_accuracy: 0.9112 - val_auc: 0.9228 - val_loss: 0.3252 - val_precision: 0.6364 - val_recall: 0.7247
# Epoch 4/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9006 - auc: 0.9158 - loss: 0.3667 - precision: 0.6401 - recall: 0.7280 - val_accuracy: 0.9150 - val_auc: 0.9236 - val_loss: 0.3079 - val_precision: 0.6547 - val_recall: 0.7198
# Epoch 5/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9059 - auc: 0.9192 - loss: 0.3531 - precision: 0.6437 - recall: 0.7462 - val_accuracy: 0.9117 - val_auc: 0.9240 - val_loss: 0.3201 - val_precision: 0.6363 - val_recall: 0.7345
# Epoch 6/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9042 - auc: 0.9235 - loss: 0.3491 - precision: 0.6434 - recall: 0.7534 - val_accuracy: 0.9095 - val_auc: 0.9237 - val_loss: 0.3289 - val_precision: 0.6266 - val_recall: 0.7375
# Epoch 7/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9025 - auc: 0.9232 - loss: 0.3519 - precision: 0.6432 - recall: 0.7459 - val_accuracy: 0.9153 - val_auc: 0.9245 - val_loss: 0.3128 - val_precision: 0.6546 - val_recall: 0.7266
# Epoch 8/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9043 - auc: 0.9180 - loss: 0.3570 - precision: 0.6382 - recall: 0.7372 - val_accuracy: 0.9151 - val_auc: 0.9251 - val_loss: 0.3085 - val_precision: 0.6529 - val_recall: 0.7286
# Epoch 9/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9024 - auc: 0.9203 - loss: 0.3546 - precision: 0.6375 - recall: 0.7476 - val_accuracy: 0.9166 - val_auc: 0.9252 - val_loss: 0.3028 - val_precision: 0.6607 - val_recall: 0.7257
# Epoch 10/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9029 - auc: 0.9216 - loss: 0.3519 - precision: 0.6366 - recall: 0.7468 - val_accuracy: 0.9151 - val_auc: 0.9256 - val_loss: 0.3056 - val_precision: 0.6529 - val_recall: 0.7286
# Epoch 11/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9011 - auc: 0.9196 - loss: 0.3579 - precision: 0.6364 - recall: 0.7488 - val_accuracy: 0.9129 - val_auc: 0.9257 - val_loss: 0.3139 - val_precision: 0.6408 - val_recall: 0.7384
# Epoch 12/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9001 - auc: 0.9220 - loss: 0.3516 - precision: 0.6295 - recall: 0.7488 - val_accuracy: 0.9132 - val_auc: 0.9256 - val_loss: 0.3158 - val_precision: 0.6419 - val_recall: 0.7384
# Epoch 13/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9011 - auc: 0.9247 - loss: 0.3470 - precision: 0.6359 - recall: 0.7495 - val_accuracy: 0.9160 - val_auc: 0.9257 - val_loss: 0.2936 - val_precision: 0.6592 - val_recall: 0.7207
# Epoch 14/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9055 - auc: 0.9257 - loss: 0.3430 - precision: 0.6452 - recall: 0.7591 - val_accuracy: 0.9056 - val_auc: 0.9258 - val_loss: 0.3268 - val_precision: 0.6093 - val_recall: 0.7453
# Epoch 15/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8932 - auc: 0.9167 - loss: 0.3679 - precision: 0.6120 - recall: 0.7443 - val_accuracy: 0.9151 - val_auc: 0.9262 - val_loss: 0.3112 - val_precision: 0.6505 - val_recall: 0.7375
# Epoch 16/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9045 - auc: 0.9249 - loss: 0.3402 - precision: 0.6308 - recall: 0.7569 - val_accuracy: 0.9086 - val_auc: 0.9263 - val_loss: 0.3272 - val_precision: 0.6215 - val_recall: 0.7443
# Epoch 17/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9044 - auc: 0.9271 - loss: 0.3390 - precision: 0.6396 - recall: 0.7570 - val_accuracy: 0.9146 - val_auc: 0.9261 - val_loss: 0.3024 - val_precision: 0.6498 - val_recall: 0.7316
# Epoch 18/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9053 - auc: 0.9254 - loss: 0.3426 - precision: 0.6466 - recall: 0.7469 - val_accuracy: 0.9103 - val_auc: 0.9260 - val_loss: 0.3202 - val_precision: 0.6284 - val_recall: 0.7434
# Epoch 19/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8992 - auc: 0.9241 - loss: 0.3517 - precision: 0.6341 - recall: 0.7530 - val_accuracy: 0.9147 - val_auc: 0.9260 - val_loss: 0.3008 - val_precision: 0.6519 - val_recall: 0.7257
# Epoch 20/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9002 - auc: 0.9212 - loss: 0.3515 - precision: 0.6240 - recall: 0.7433 - val_accuracy: 0.9150 - val_auc: 0.9263 - val_loss: 0.3048 - val_precision: 0.6510 - val_recall: 0.7335
# Epoch 21/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9022 - auc: 0.9252 - loss: 0.3472 - precision: 0.6401 - recall: 0.7631 - val_accuracy: 0.9134 - val_auc: 0.9262 - val_loss: 0.3086 - val_precision: 0.6427 - val_recall: 0.7394
# Epoch 22/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9020 - auc: 0.9263 - loss: 0.3434 - precision: 0.6304 - recall: 0.7565 - val_accuracy: 0.9102 - val_auc: 0.9261 - val_loss: 0.3176 - val_precision: 0.6290 - val_recall: 0.7384
# Epoch 23/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9011 - auc: 0.9242 - loss: 0.3472 - precision: 0.6300 - recall: 0.7519 - val_accuracy: 0.9090 - val_auc: 0.9262 - val_loss: 0.3129 - val_precision: 0.6241 - val_recall: 0.7394
# Epoch 24/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9047 - auc: 0.9281 - loss: 0.3387 - precision: 0.6428 - recall: 0.7650 - val_accuracy: 0.9112 - val_auc: 0.9262 - val_loss: 0.3095 - val_precision: 0.6339 - val_recall: 0.7355
# Epoch 25/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9026 - auc: 0.9282 - loss: 0.3389 - precision: 0.6370 - recall: 0.7625 - val_accuracy: 0.9119 - val_auc: 0.9261 - val_loss: 0.3142 - val_precision: 0.6358 - val_recall: 0.7414
# Epoch 26/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9010 - auc: 0.9232 - loss: 0.3476 - precision: 0.6244 - recall: 0.7589 - val_accuracy: 0.9060 - val_auc: 0.9262 - val_loss: 0.3257 - val_precision: 0.6099 - val_recall: 0.7502
# Epoch 27/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8986 - auc: 0.9237 - loss: 0.3459 - precision: 0.6133 - recall: 0.7604 - val_accuracy: 0.9100 - val_auc: 0.9258 - val_loss: 0.3167 - val_precision: 0.6278 - val_recall: 0.7414
# Epoch 28/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8986 - auc: 0.9276 - loss: 0.3414 - precision: 0.6221 - recall: 0.7535 - val_accuracy: 0.9090 - val_auc: 0.9262 - val_loss: 0.3147 - val_precision: 0.6245 - val_recall: 0.7375
# Epoch 29/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9031 - auc: 0.9293 - loss: 0.3359 - precision: 0.6341 - recall: 0.7584 - val_accuracy: 0.9081 - val_auc: 0.9256 - val_loss: 0.3261 - val_precision: 0.6191 - val_recall: 0.7463
# Epoch 30/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9016 - auc: 0.9238 - loss: 0.3485 - precision: 0.6308 - recall: 0.7556 - val_accuracy: 0.9127 - val_auc: 0.9259 - val_loss: 0.3090 - val_precision: 0.6397 - val_recall: 0.7384
# Epoch 31/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9021 - auc: 0.9278 - loss: 0.3379 - precision: 0.6290 - recall: 0.7549 - val_accuracy: 0.9076 - val_auc: 0.9258 - val_loss: 0.3165 - val_precision: 0.6178 - val_recall: 0.7424
# Epoch 32/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9073 - auc: 0.9270 - loss: 0.3360 - precision: 0.6408 - recall: 0.7729 - val_accuracy: 0.9074 - val_auc: 0.9258 - val_loss: 0.3179 - val_precision: 0.6159 - val_recall: 0.7473
# Epoch 33/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8991 - auc: 0.9266 - loss: 0.3439 - precision: 0.6242 - recall: 0.7728 - val_accuracy: 0.9122 - val_auc: 0.9256 - val_loss: 0.3081 - val_precision: 0.6382 - val_recall: 0.7355
# Epoch 34/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9019 - auc: 0.9295 - loss: 0.3349 - precision: 0.6296 - recall: 0.7647 - val_accuracy: 0.9098 - val_auc: 0.9250 - val_loss: 0.3126 - val_precision: 0.6274 - val_recall: 0.7384
# Epoch 35/35
# 288/288 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9009 - auc: 0.9269 - loss: 0.3373 - precision: 0.6167 - recall: 0.7640 - val_accuracy: 0.9077 - val_auc: 0.9256 - val_loss: 0.3192 - val_precision: 0.6178 - val_recall: 0.7453

# %% [markdown]
# Trainin visualisation

# %%
plt.figure(figsize=(12, 4))

# Wykres funkcji straty (Loss)
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Strata (Loss)')
plt.xlabel('Epoka')
plt.legend()

# Wykres metryki AUC
plt.subplot(1, 2, 2)
plt.plot(history.history['auc'], label='Train AUC')
plt.plot(history.history['val_auc'], label='Val AUC')
plt.title('Jakość modelu (AUC)')
plt.xlabel('Epoka')
plt.legend()

plt.show()

# %% [markdown]
# 1. First training
# After first training model performed poorly, even after changing threshold from 0.8 to 0.5, learning rate from 0.01 to 0.005 to 0.0005 and increasing the batch size. Eventually model decided that the lowest loss it can achive is by ignoring all rain and resulting in almost zero recal: 0.0046.
#
# The best recal model managed to get is around 0.2 with learning rate 0.005, batch size 64, epochs 30 and threshold 0.5.
#
# In conclussion the model seems to complex for the one neuron to be able to train properly. The unbalanced dataset with small amount of rain might also be the issue and the model might need punishment for ignoring the rain cases.

# %% [markdown]
# 2. After adding the dense 32 layer
#
# **AUC** improved from 0.6 to 0.8 - the model can diffenciate the rain from no rain better
#
# **Precision** improved from 0.4 to 0.6 - model finds less false alarms (false positive cases)
#
# **Recall** still didn't improve and stays around 0.1 which means the unbalanced dataset is a real issue and the model needs a punishment for ignoring most of the rain cases

# %% [markdown]
# 3, 4. After the fixes and changes the model seems to have improved significantly:
#
# accuracy: 0.8065 - auc: 0.9060 - loss: 0.3797 - precision: 0.4087 - recall: 0.8535
#
# The model can diffrenciate the cases very well, still calls a lot false alarms, however it also catches a lot more rain cases.
